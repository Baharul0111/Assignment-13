# %%
#question 1
'''In Python, it's recommended to use the Exception class as a foundation for creating your own custom exceptions. 
This ensures consistency with how Python handles exceptions and makes your custom exceptions easily recognizable and compatible with existing code. 
It's like speaking the same exception language, enhancing code clarity and ease of use.'''
# Out:
# "In Python, it's recommended to use the Exception class as a foundation for creating your own custom exceptions. \nThis ensures consistency with how Python handles exceptions and makes your custom exceptions easily recognizable and compatible with existing code. \nIt's like speaking the same exception language, enhancing code clarity and ease of use."

# %%
#question 2
import inspect as ipt
def tree_class(cls, ind = 0):
    print ('-' * ind, cls.__name__)
    for K in cls.__subclasses__():
        tree_class(K, ind + 3)
print ("Inbuilt exceptions is: ")

ipt.getclasstree(ipt.getmro(BaseException))

tree_class(BaseException)
# Out:
# Inbuilt exceptions is:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# ------------ PackageNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- ItimerError
# --------- herror
# --------- gaierror
# --------- timeout
# --------- SSLError
# ...

# %%
#question 3
''' Two exceptions derived from ArithmeticError are ZeroDivisionError and OverflowError. '''
import logging
logging.basicConfig(filename="test.log", level=logging.DEBUG)
try:
    a = 10 / 0 
except ZeroDivisionError as zde:
    logging.error("Caught ZeroDivisionError: {}".format(zde))
    print("Caught ZeroDivisionError: ", zde)
    
try:
    a = 2 ** 1000  
except OverflowError as oe:
    logging.error("Caught OverflowError: {}".format(oe))
    print("Caught OverflowError: ", oe)
# Out:
# Caught ZeroDivisionError:  division by zero

# %%
#question 4
'''The LookupError class in Python is a base class for exceptions that occur when a key or index used to access an element in a data structure is invalid or not found. Two common exceptions derived from LookupError are KeyError and IndexError.'''
my_dict = {'a': 1, 'b': 2, 'c': 3}
try:
    value = my_dict['d']
except KeyError as ke:
    logging.error(ke)
    print("Caught KeyError: ", ke)

my_list = [1, 2, 3]
try:
    value = my_list[5] 
except IndexError as ie:
    logging.error(ie)
    print("Caught IndexError: ", ie)
# Out:
# Caught KeyError:  'd'
# Caught IndexError:  list index out of range

# %%
#question 5
'''ImportError is a base class for exceptions raised when an import statement fails to locate or load a module. This can happen for various reasons, such as the module not being installed, having a syntax error, or being unavailable in the current context.'''
'''ModuleNotFoundError is a subclass of ImportError introduced in Python 3.6. It is more specific and raised when the requested module cannot be found.'''
# Out:
# 'ModuleNotFoundError is a subclass of ImportError introduced in Python 3.6. It is more specific and raised when the requested module cannot be found.'

# %%
#question 6
'''use always a specific exception'''
'''print always a proper message'''
'''always try to log your error'''
'''alwyas avoid to write a multiple exception handling'''
'''cleanup all the resources'''
# Out:
# 'cleanup all the resources'
